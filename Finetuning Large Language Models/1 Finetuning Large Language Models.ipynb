# %% [markdown]
# ## Finetuning Large Language Models
#
# In this, we'll explore how we can take an open-source LLM and further train with your own data. Using finetuning you can adjust LLM tone,
# ![image.png](attachment:97750d38-edc0-4e25-b65e-988e02d87ce4.png)

# %% [markdown]
# ### Why finetune ?
# Why do we fineture, what finetune is ? compared to prompt engineering and go through a lab where we'll compare a fine tuned model and a non file tuned model.
# Finetuning is like taking general purpose models and specializing them into something like ChatGPT, Github Copilot etc.
# ![image.png](attachment:683d0e6c-a386-42ea-b46d-8263a2945a10.png)
# ![image.png](attachment:09f2a133-596a-443a-83c5-6fcdd1eeee03.png)
# ![image.png](attachment:46457ce4-965a-48cf-bca9-8554e44d693b.png)

# %% [markdown]
# ![image.png](attachment:a3f2c5b3-cc3d-4c1e-a90c-8a6ca0ad13ff.png)
# ![image.png](attachment:9d0dcd28-8982-480d-9ee1-b5d8faf203d4.png)

# %% [markdown]
# ![image.png](attachment:069ef5e3-007d-4b77-a786-f35285b583ee.png)
